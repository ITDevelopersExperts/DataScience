# %% [markdown]
# ## **CoderHouse** After Class Pandas Parte 2

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Ejercicio 1
# Junto a este Notebook encontrarás un archivo llamado `"pooled_data_public.dta"` que contiene la base de datos completa del BID. Este archivo, al ser de tipo *.dta*, requiere de una función de `pandas` para ser importado a Python.
#
#     read_stata(file = "pooled_data_public.dta")
#
# Implementa una función llamada `importar_e_indexar` que no reciba parámetros, importe los datos del archivo `"pooled_data_public.dta"` y retorne un `DataFrame` cuyo índice (`index`) sea la columna `'id'` de la base de datos sin incluirla en las columnas del `DataFrame` resultante.
#
# La función debe retornar un `DataFrame`.

# %%
# Solución
def importar_e_indexar(): 
    DataFrame = pd.read_stata("pooled_data_public.dta", index_col='id') 
    return DataFrame 

df = importar_e_indexar()
# Out:
#            country_code country_name      weight   weight_pop           pop  \
# id
# 1000060.0       Bahamas      Bahamas  647.764465  2226.561768  3.514610e+05
# 1000734.0       Bahamas      Bahamas    9.053495    31.119595  3.514610e+05
# 1000057.0       Bahamas      Bahamas    0.413436     1.421105  3.514610e+05
# 1000120.0       Bahamas      Bahamas   26.383644    90.688545  3.514610e+05
# 1000235.0       Bahamas      Bahamas    6.756267    23.223328  3.514610e+05
# ...                 ...          ...         ...          ...           ...
# 17001614.0      Uruguay      Uruguay   26.455542    70.345154  3.530912e+06
# 17017448.0      Uruguay      Uruguay    3.855343    10.251338  3.530912e+06
# 17013032.0      Uruguay      Uruguay    0.098829     0.262786  3.530912e+06
# 17014760.0      Uruguay      Uruguay         NaN          NaN  3.530912e+06
# 17003990.0      Uruguay      Uruguay   29.191914    77.621147  3.530912e+06
#
#            recordeddate    genero  edad            educ  \
# id
# 1000060.0    2020-04-18  Femenino    20      Secundaria
# 1000734.0    2020-04-16  Femenino    34     Universidad
# 1000057.0    2020-04-20  Femenino    22   Tecnica/Voca.
# 1000120.0    2020-04-19  Femenino    64   Tecnica/Voca.
# 1000235.0    2020-04-16  Femenino    44  Maestria o mas
# ...                 ...       ...   ...             ...
# 17001614.0   2020-04-15  Femenino    30      Secundaria
# 17017448.0   2020-04-15  Femenino    42   Tecnica/Voca.
# 17013032.0   2020-04-05  Femenino    21   Tecnica/Voca.
# 17014760.0   2020-04-06  Femenino    49  Maestria o mas
# 17003990.0   2020-04-05  Femenino    42      Secundaria
#
#                             estcivil  ...  medios_covid_periodicos  \
# id                                    ...
# 1000060.0   soltero/a / divorciado/a  ...                  Siempre
# 1000734.0          Casado/a / pareja  ...                  A veces
# 1000057.0   soltero/a / divorciado/a  ...                      -99
# 1000120.0          Casado/a / pareja  ...                  A veces
# 1000235.0          Casado/a / pareja  ...                    Nunca
# ...                              ...  ...                      ...
# 17001614.0  soltero/a / divorciado/a  ...             Casi siempre
# 17017448.0         Casado/a / pareja  ...                  A veces
# 17013032.0  soltero/a / divorciado/a  ...                  Siempre
# 17014760.0         Casado/a / pareja  ...                  Siempre
# 17003990.0  soltero/a / divorciado/a  ...                  A veces
#
#             medios_covid_tv medios_covid_radio nps_medio_redessoc  \
# id
# 1000060.0           A veces              Nunca                 No
# 1000734.0      Casi siempre       Casi siempre                 Si
# 1000057.0           Siempre                -99                 No
# 1000120.0           Siempre            Siempre                 No
# 1000235.0           A veces              Nunca                 No
# ...                     ...                ...                ...
# 17001614.0          Siempre       Casi siempre                 No
# 17017448.0          A veces              Nunca                 No
# 17013032.0          Siempre            Siempre                 No
# 17014760.0     Casi siempre       Casi siempre                 No
# 17003990.0     Casi siempre       Casi siempre                 No
#
#             nps_medio_sms  nps_medio_periodico nps_medio_tv  nps_medio_radio  \
# id
# 1000060.0              No                   No           No               No
# 1000734.0              Si                   No           Si               Si
# 1000057.0              No                   No           No               No
# 1000120.0              No                   No           Si               Si
# 1000235.0              No                   No           No               No
# ...                   ...                  ...          ...              ...
# 17001614.0             No                   No           Si               No
# 17017448.0             No                   No           No               No
# 17013032.0             No                   No           No               No
# 17014760.0             No                   No           No               No
# 17003990.0             No                   No           No               No
#
#            nps_medio_website nps_medio_otro
# id
# 1000060.0                 No             No
# 1000734.0                 No             No
# 1000057.0                 No             No
# 1000120.0                 No             Si
# 1000235.0                 Si             No
# ...                      ...            ...
# 17001614.0                No             No
# 17017448.0                No             No
# 17013032.0                No             No
# 17014760.0                No             No
# 17003990.0                No             No
#
# [230509 rows x 128 columns]

# %% [markdown]
# ### Ejercicio 2
#
# Para continuar un análisis de datos:
# 1. Elimine todas las filas que tengan valores NaN
# 2. Reporte las primeras 15 líneas del dataframe cargado, luego de la depuración.
# 3. Describa el set de datos.
# 4. ¿cual es la media de los pesos por país?

# %%
# Solución 1
df = importar_e_indexar()
df_sinNaN = df.dropna()

df_sinNaN
# Out:
#                    country_code         country_name      weight   weight_pop  \
# id
# 1000734.0               Bahamas              Bahamas    9.053495    31.119595
# 1000828.0               Bahamas              Bahamas   43.714005   150.258224
# 1000878.0               Bahamas              Bahamas  205.270889   705.577942
# 1000343.0               Bahamas              Bahamas    2.210451     7.597987
# 1000064.0               Bahamas              Bahamas    6.872893    23.624208
# ...                         ...                  ...         ...          ...
# 16003650.0  Trinidad and Tobago  Trinidad and Tobago  125.022942   576.058289
# 16003150.0  Trinidad and Tobago  Trinidad and Tobago   61.249310   282.213593
# 16000175.0  Trinidad and Tobago  Trinidad and Tobago   84.402596   388.895142
# 16002654.0  Trinidad and Tobago  Trinidad and Tobago  380.965790  1755.345825
# 16001743.0  Trinidad and Tobago  Trinidad and Tobago   76.479713   352.389526
#
#                   pop recordeddate     genero  edad            educ  \
# id
# 1000734.0    351461.0   2020-04-16   Femenino    34     Universidad
# 1000828.0    351461.0   2020-04-21   Femenino    43  Maestria o mas
# 1000878.0    351461.0   2020-04-16  Masculino    55  Maestria o mas
# 1000343.0    351461.0   2020-04-18   Femenino    31      Secundaria
# 1000064.0    351461.0   2020-04-18   Femenino    54     Universidad
# ...               ...          ...        ...   ...             ...
# 16003650.0  2595164.0   2020-04-17   Femenino    45      Secundaria
# 16003150.0  2595164.0   2020-04-16   Femenino    38     Universidad
# 16000175.0  2595164.0   2020-04-16   Femenino    41     Universidad
# 16002654.0  2595164.0   2020-04-17  Masculino    41   Tecnica/Voca.
# 16001743.0  2595164.0   2020-04-17   Femenino    28        Primaria
#
#                             estcivil  ...  medios_covid_periodicos  \
# id                                    ...
# 1000734.0          Casado/a / pareja  ...                  A veces
# 1000828.0          Casado/a / pareja  ...                  A veces
# 1000878.0   soltero/a / divorciado/a  ...             Casi siempre
# 1000343.0                       Otro  ...                  Siempre
# 1000064.0   soltero/a / divorciado/a  ...             Casi siempre
# ...                              ...  ...                      ...
# 16003650.0         Casado/a / pareja  ...                  A veces
# 16003150.0         Casado/a / pareja  ...                  A veces
# 16000175.0  soltero/a / divorciado/a  ...                  Siempre
# 16002654.0  soltero/a / divorciado/a  ...                  A veces
# 16001743.0  soltero/a / divorciado/a  ...                  Siempre
#
#             medios_covid_tv medios_covid_radio nps_medio_redessoc  \
# id
# 1000734.0      Casi siempre       Casi siempre                 Si
# 1000828.0           A veces              Nunca                 No
# 1000878.0      Casi siempre              Nunca                 No
# 1000343.0           Siempre              Nunca                 Si
# 1000064.0           Siempre       Casi siempre                 No
# ...                     ...                ...                ...
# 16003650.0          A veces            A veces                 No
# 16003150.0          Siempre              Nunca                 No
# 16000175.0          Siempre            A veces                 No
# 16002654.0            Nunca              Nunca                 No
# 16001743.0          Siempre            Siempre                 No
#
#             nps_medio_sms  nps_medio_periodico nps_medio_tv  nps_medio_radio  \
# id
# 1000734.0              Si                   No           Si               Si
# 1000828.0              No                   No           No               No
# 1000878.0              No                   No           No               No
# 1000343.0              No                   No           No               No
# 1000064.0              No                   No           No               No
# ...                   ...                  ...          ...              ...
# 16003650.0             No                   No           No               No
# 16003150.0             No                   No           No               No
# 16000175.0             No                   No           No               No
# 16002654.0             No                   No           No               No
# 16001743.0             No                   No           No               No
#
#            nps_medio_website nps_medio_otro
# id
# 1000734.0                 No             No
# 1000828.0                 No             No
# 1000878.0                 Si             No
# 1000343.0                 No             No
# 1000064.0                 No             No
# ...                      ...            ...
# 16003650.0                No             No
# 16003150.0                No             No
# 16000175.0                No             No
# 16002654.0                No             No
# 16001743.0                No             No
#
# [46930 rows x 128 columns]

# %%
# Solución 2

# %%
# Solución 3

# %%
# Solución 4

# %% [markdown]
# ### Ejercicio 3
# Implementa una función llamada `sin_columnas` que no reciba parámetros, tome el `DataFrame` resultante del [Ejercicio 1] y lo retorne sin las columnas `"country_name"`, `"grado"` y `"coima"`.
#
# Debes hacer uso del método `drop`.
#
# La función debe retornar un `DataFrame`.

# %%
# Solución 1

# %% [markdown]
# ### Ejercicio 4
# A raiz de la pandemia, los gobiernos de latinoamérica desean monitorear a aquellas personas que salen de sus casas a trabajar y conviven con personas mayores de 60 años.
#
# Implementa una función llamada `trabajo_afuera_y_mayores` que no reciba parámetros, tome el `DataFrame` resultante del [Ejercicio 1] y lo retorne únicamente con los registros que en la columna `"trabajocasa"` tengan el valor `"Fuera de su casa"` y que en la columna `"haymayores"` tengan el valor `"si"`.
#
# La función debe retornar un `DataFrame`.

# %%
# Solución

# %% [markdown]
# ### Ejercicio 5
#
# Implementa una función llamada `hogares_decrecen` que no reciba parámetros, tome el `DataFrame` resultante del [Ejercicio 1](#Ejercicio-1) y retorne un `DataFrame` únicamente con las columnas `"nrhogar"`, `"nrhogar_antes"` y una columna adicional llamada `"hogar_decrecio"` que para cada registro tome un valor de:
#
# * `1`, si el valor numérico de la columna `"nrhogar"` es menor que el valor de la columna `"nrhogar_antes"`;
#
# * `0`, de lo contrario.
#
# La función debe retornar un `DataFrame`.

# %%
# Solucion
