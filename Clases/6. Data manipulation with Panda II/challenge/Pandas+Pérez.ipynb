# %% [markdown]
# | <center>Desafío<center> | <center>Alumno<center> |
# | :---: | :---: |
# | `03` | Pérez, Gastón |

# %% [markdown]
# # Punto 01
# ### Con este archivo, construir un objeto de series de tiempo con el índice igual al año de los juegos olímpicos

# %% [markdown]
# Previo a comenzar con el desarrollo, importo las librerías necesarias para el mismo.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Luego, importa el dataset; que en este caso está contenido en mi unidad local.

# %%
df_juegosOlimpicos = pd.read_csv("Summer-Olympic-medals-1976-to-2008.csv")
df_juegosOlimpicos.dropna(subset=["Year"], inplace=True)  #elimino registros nulos
#df_juegosOlimpicos.set_index("Year", inplace = True)  #cambio el index por la columna year
df_juegosOlimpicos
# Out:
#            City    Year      Sport       Discipline           Event  \
# 0      Montreal  1976.0   Aquatics           Diving  3m springboard
# 1      Montreal  1976.0   Aquatics           Diving  3m springboard
# 2      Montreal  1976.0   Aquatics           Diving  3m springboard
# 3      Montreal  1976.0   Aquatics           Diving  3m springboard
# 4      Montreal  1976.0   Aquatics           Diving    10m platform
# ...         ...     ...        ...              ...             ...
# 15428   Beijing  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg
# 15429   Beijing  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg
# 15430   Beijing  2008.0  Wrestling  Wrestling Gre-R       55 - 60kg
# 15431   Beijing  2008.0  Wrestling  Wrestling Gre-R       60 - 66kg
# 15432   Beijing  2008.0  Wrestling  Wrestling Gre-R      96 - 120kg
#
#                         Athlete Gender Country_Code        Country  \
# 0               K�HLER, Christa  Women          GDR   East Germany
# ...

# %%
df_juegosOlimpicos["Year"] = pd.to_datetime(df_juegosOlimpicos["Year"], format='%Y')
df_juegosOlimpicos
# Out:
#            City       Year      Sport       Discipline           Event  \
# 0      Montreal 1976-01-01   Aquatics           Diving  3m springboard
# 1      Montreal 1976-01-01   Aquatics           Diving  3m springboard
# 2      Montreal 1976-01-01   Aquatics           Diving  3m springboard
# 3      Montreal 1976-01-01   Aquatics           Diving  3m springboard
# 4      Montreal 1976-01-01   Aquatics           Diving    10m platform
# ...         ...        ...        ...              ...             ...
# 15428   Beijing 2008-01-01  Wrestling  Wrestling Gre-R       66 - 74kg
# 15429   Beijing 2008-01-01  Wrestling  Wrestling Gre-R       66 - 74kg
# 15430   Beijing 2008-01-01  Wrestling  Wrestling Gre-R       55 - 60kg
# 15431   Beijing 2008-01-01  Wrestling  Wrestling Gre-R       60 - 66kg
# 15432   Beijing 2008-01-01  Wrestling  Wrestling Gre-R      96 - 120kg
#
#                         Athlete Gender Country_Code        Country  \
# ...

# %% [markdown]
# **Cambio el índice por el año de los juegos olímpicos**

# %%
pd.DatetimeIndex(df_juegosOlimpicos["Year"]).year
indexYear = pd.DatetimeIndex(df_juegosOlimpicos["Year"]).year
indexYear
# Out:
# Int64Index([1976, 1976, 1976, 1976, 1976, 1976, 1976, 1976, 1976, 1976,
#             ...
#             2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008],
#            dtype='int64', name='Year', length=15316)

# %%
df_juegosOlimpicos
# Out:
#                 City      Sport       Discipline           Event  \
# Year
# 1976-01-01  Montreal   Aquatics           Diving  3m springboard
# 1976-01-01  Montreal   Aquatics           Diving  3m springboard
# 1976-01-01  Montreal   Aquatics           Diving  3m springboard
# 1976-01-01  Montreal   Aquatics           Diving  3m springboard
# 1976-01-01  Montreal   Aquatics           Diving    10m platform
# ...              ...        ...              ...             ...
# 2008-01-01   Beijing  Wrestling  Wrestling Gre-R       66 - 74kg
# 2008-01-01   Beijing  Wrestling  Wrestling Gre-R       66 - 74kg
# 2008-01-01   Beijing  Wrestling  Wrestling Gre-R       55 - 60kg
# 2008-01-01   Beijing  Wrestling  Wrestling Gre-R       60 - 66kg
# 2008-01-01   Beijing  Wrestling  Wrestling Gre-R      96 - 120kg
#
#                              Athlete Gender Country_Code        Country  \
# Year
# 1976-01-01           K�HLER, Christa  Women          GDR   East Germany
# ...

# %% [markdown]
# Para verificar que funciona, podemos filtrar al país que ganó más medallas desde el año 1980.

# %%
medals = pd.Series(df_juegosOlimpicos['Country'].values,index=indexYear)
filtro = (Serie_medallas.index >= 1980)
medals[filtro]
# Out:
# Year
# 1980    East Germany
# 1980    East Germany
# 1980    Soviet Union
# 1980    Soviet Union
# 1980          Mexico
#             ...
# 2008          France
# 2008         Georgia
# 2008      Azerbaijan
# 2008          France
# 2008            Cuba
# Length: 14011, dtype: object

# %% [markdown]
# # Punto 2
# ### Separo nombres de apellidos en dos columnas distintas usando la coma como separador

# %%
df_juegosOlimpicos[["Nombre","Apellido"]] = df_juegosOlimpicos["Athlete"].str.split(",",1,expand=True)
df_juegosOlimpicos.head()   #verifico que separé correctamente los nombres y apellidos
# Out:
#                 City     Sport Discipline           Event  \
# Year
# 1976-01-01  Montreal  Aquatics     Diving  3m springboard
# 1976-01-01  Montreal  Aquatics     Diving  3m springboard
# 1976-01-01  Montreal  Aquatics     Diving  3m springboard
# 1976-01-01  Montreal  Aquatics     Diving  3m springboard
# 1976-01-01  Montreal  Aquatics     Diving    10m platform
#
#                              Athlete Gender Country_Code        Country  \
# Year
# 1976-01-01           K�HLER, Christa  Women          GDR   East Germany
# 1976-01-01       KOSENKOV, Aleksandr    Men          URS   Soviet Union
# 1976-01-01      BOGGS, Philip George    Men          USA  United States
# 1976-01-01  CAGNOTTO, Giorgio Franco    Men          ITA          Italy
# 1976-01-01    WILSON, Deborah Keplar  Women          USA  United States
#
#            Event_gender   Medal    Nombre         Apellido
# Year
# 1976-01-01            W  Silver    K�HLER          Christa
# ...

# %% [markdown]
# # Punto 03
# ### 1. Obtener medidas resumen del conjunto de datos. Cuál es el país que ganó más medallas?
# ### 2. Construir una tabla que muestre cuántas medallas obtuvieron los hombres en total en cada año que se realizó el evento.

# %% [markdown]
# Creo una Dataframe que contenga la cantidad de medallas por país.

# %%
medals = df_juegosOlimpicos.groupby("Country")["Medal"].count()
df_medals = pd.DataFrame(medals)
df_medals
# Out:
#                  Medal
# Country
# Afghanistan          1
# Algeria             14
# Argentina          153
# Armenia              9
# Australia          798
# ...                ...
# Virgin Islands*      1
# West Germany       345
# Yugoslavia         278
# Zambia               2
# Zimbabwe            23
#
# [127 rows x 1 columns]

# %% [markdown]
# Accedo a partir de la serie creada, a aquel país que obtuvo más medallas (y la cantidad de las mismas).

# %%
medalsMax = medals.idxmax()
countMedals = medals.get(medalsMax) 

print("El país que más medallas ganó fue '"+str(medalsMax)+"'. El total de medallas que obtuvo fue =",countMedals)
# Out:
# El país que más medallas ganó fue 'United States'. El total de medallas que obtuvo fue = 1992

# %% [markdown]
# # Punto 4
# ### Construir una tabla que muestre cuántas medallas obtuvieron los hombres en total en cada año que se realizó el evento.

# %%
menYears = df_juegosOlimpicos.groupby(["Year", "Gender"]).filter(lambda x: any(x['Gender'] == 'Men'))
menYears = menYears.groupby("Year")['Medal'].count()
df_mens = pd.DataFrame(menYears)
df_mens
# Out:
#             Medal
# Year
# 1976-01-01    924
# 1980-01-01    958
# 1984-01-01    973
# 1988-01-01   1011
# 1992-01-01   1105
# 1996-01-01   1082
# 2000-01-01   1126
# 2004-01-01   1099
# 2008-01-01   1110
